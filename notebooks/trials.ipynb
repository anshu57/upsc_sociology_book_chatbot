# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_experimental.text_splitter import SemanticChunker
from langchain_huggingface import HuggingFaceEmbeddings
from dotenv import load_dotenv

# %%
from IPython.display import Markdown

# %%
load_dotenv()
# Out:
# True

# %%
def load_pdf_files(data):
    loader = DirectoryLoader(
        data,
        glob= "*.pdf",
        loader_cls=PyPDFLoader
    )

    documents = loader.load()
    return documents

# %%
extracted_data = load_pdf_files('/Users/anshugangwar/Desktop/Anshu/upsc_sociology_book_chatbot/data/')
# Out:
# Ignoring wrong pointing object 99 0 (offset 0)
# Ignoring wrong pointing object 100 0 (offset 0)
# Ignoring wrong pointing object 101 0 (offset 0)
# Ignoring wrong pointing object 102 0 (offset 0)
# Ignoring wrong pointing object 103 0 (offset 0)
# Ignoring wrong pointing object 104 0 (offset 0)
# Ignoring wrong pointing object 105 0 (offset 0)
# Ignoring wrong pointing object 107 0 (offset 0)
# Ignoring wrong pointing object 140 0 (offset 0)
# Ignoring wrong pointing object 141 0 (offset 0)
# Ignoring wrong pointing object 142 0 (offset 0)
# Ignoring wrong pointing object 143 0 (offset 0)
# Ignoring wrong pointing object 144 0 (offset 0)
# Ignoring wrong pointing object 145 0 (offset 0)
# Ignoring wrong pointing object 146 0 (offset 0)
# Ignoring wrong pointing object 148 0 (offset 0)
# Ignoring wrong pointing object 175 0 (offset 0)
# Ignoring wrong pointing object 176 0 (offset 0)
# Ignoring wrong pointing object 177 0 (offset 0)
# Ignoring wrong pointing object 178 0 (offset 0)
# Ignoring wrong pointing object 179 0 (offset 0)
# Ignoring wrong pointing object 180 0 (offset 0)
# Ignoring wrong pointing object 181 0 (offset 0)
# Ignoring wrong pointing object 183 0 (offset 0)
# Ignoring wrong pointing object 216 0 (offset 0)
# Ignoring wrong pointing object 217 0 (offset 0)
# Ignoring wrong pointing object 218 0 (offset 0)
# Ignoring wrong pointing object 219 0 (offset 0)
# Ignoring wrong pointing object 220 0 (offset 0)
# Ignoring wrong pointing object 221 0 (offset 0)
# Ignoring wrong pointing object 222 0 (offset 0)
# Ignoring wrong pointing object 224 0 (offset 0)
# Ignoring wrong pointing object 257 0 (offset 0)
# Ignoring wrong pointing object 258 0 (offset 0)
# Ignoring wrong pointing object 259 0 (offset 0)
# Ignoring wrong pointing object 260 0 (offset 0)
# Ignoring wrong pointing object 261 0 (offset 0)
# Ignoring wrong pointing object 262 0 (offset 0)
# Ignoring wrong pointing object 263 0 (offset 0)
# Ignoring wrong pointing object 265 0 (offset 0)
# Ignoring wrong pointing object 295 0 (offset 0)
# Ignoring wrong pointing object 296 0 (offset 0)
# Ignoring wrong pointing object 297 0 (offset 0)
# Ignoring wrong pointing object 298 0 (offset 0)
# Ignoring wrong pointing object 299 0 (offset 0)
# Ignoring wrong pointing object 300 0 (offset 0)
# Ignoring wrong pointing object 301 0 (offset 0)
# Ignoring wrong pointing object 303 0 (offset 0)
# Ignoring wrong pointing object 333 0 (offset 0)
# Ignoring wrong pointing object 334 0 (offset 0)
# Ignoring wrong pointing object 335 0 (offset 0)
# Ignoring wrong pointing object 336 0 (offset 0)
# Ignoring wrong pointing object 337 0 (offset 0)
# Ignoring wrong pointing object 338 0 (offset 0)
# Ignoring wrong pointing object 339 0 (offset 0)
# Ignoring wrong pointing object 341 0 (offset 0)
# Ignoring wrong pointing object 371 0 (offset 0)
# Ignoring wrong pointing object 372 0 (offset 0)
# Ignoring wrong pointing object 373 0 (offset 0)
# Ignoring wrong pointing object 374 0 (offset 0)
# Ignoring wrong pointing object 375 0 (offset 0)
# Ignoring wrong pointing object 376 0 (offset 0)
# Ignoring wrong pointing object 377 0 (offset 0)
# Ignoring wrong pointing object 379 0 (offset 0)
# Ignoring wrong pointing object 409 0 (offset 0)
# Ignoring wrong pointing object 410 0 (offset 0)
# Ignoring wrong pointing object 411 0 (offset 0)
# Ignoring wrong pointing object 412 0 (offset 0)
# Ignoring wrong pointing object 413 0 (offset 0)
# Ignoring wrong pointing object 414 0 (offset 0)
# Ignoring wrong pointing object 415 0 (offset 0)
# Ignoring wrong pointing object 417 0 (offset 0)
# Ignoring wrong pointing object 450 0 (offset 0)
# Ignoring wrong pointing object 451 0 (offset 0)
# Ignoring wrong pointing object 452 0 (offset 0)
# Ignoring wrong pointing object 453 0 (offset 0)
# Ignoring wrong pointing object 454 0 (offset 0)
# Ignoring wrong pointing object 455 0 (offset 0)
# Ignoring wrong pointing object 456 0 (offset 0)
# Ignoring wrong pointing object 458 0 (offset 0)
# Ignoring wrong pointing object 491 0 (offset 0)
# Ignoring wrong pointing object 492 0 (offset 0)
# Ignoring wrong pointing object 493 0 (offset 0)
# Ignoring wrong pointing object 494 0 (offset 0)
# Ignoring wrong pointing object 495 0 (offset 0)
# Ignoring wrong pointing object 496 0 (offset 0)
# Ignoring wrong pointing object 497 0 (offset 0)
# Ignoring wrong pointing object 499 0 (offset 0)
# Ignoring wrong pointing object 523 0 (offset 0)
# Ignoring wrong pointing object 524 0 (offset 0)
# Ignoring wrong pointing object 525 0 (offset 0)
# Ignoring wrong pointing object 526 0 (offset 0)
# Ignoring wrong pointing object 527 0 (offset 0)
# Ignoring wrong pointing object 528 0 (offset 0)
# Ignoring wrong pointing object 529 0 (offset 0)
# Ignoring wrong pointing object 531 0 (offset 0)
# Ignoring wrong pointing object 561 0 (offset 0)
# Ignoring wrong pointing object 564 0 (offset 0)
# Ignoring wrong pointing object 567 0 (offset 0)
# Ignoring wrong pointing object 570 0 (offset 0)
# Ignoring wrong pointing object 573 0 (offset 0)
# Ignoring wrong pointing object 577 0 (offset 0)
# Ignoring wrong pointing object 580 0 (offset 0)
# Ignoring wrong pointing object 585 0 (offset 0)
# Ignoring wrong pointing object 588 0 (offset 0)
# Ignoring wrong pointing object 591 0 (offset 0)
# Ignoring wrong pointing object 595 0 (offset 0)
# Ignoring wrong pointing object 598 0 (offset 0)
# Ignoring wrong pointing object 601 0 (offset 0)
# Ignoring wrong pointing object 604 0 (offset 0)
# Ignoring wrong pointing object 607 0 (offset 0)
# Ignoring wrong pointing object 610 0 (offset 0)
# Ignoring wrong pointing object 614 0 (offset 0)
# Ignoring wrong pointing object 617 0 (offset 0)
# Ignoring wrong pointing object 620 0 (offset 0)
# Ignoring wrong pointing object 623 0 (offset 0)
# Ignoring wrong pointing object 626 0 (offset 0)
# Ignoring wrong pointing object 629 0 (offset 0)
# Ignoring wrong pointing object 633 0 (offset 0)
# Ignoring wrong pointing object 636 0 (offset 0)
# Ignoring wrong pointing object 639 0 (offset 0)
# Ignoring wrong pointing object 642 0 (offset 0)
# Ignoring wrong pointing object 646 0 (offset 0)
# Ignoring wrong pointing object 649 0 (offset 0)
# Ignoring wrong pointing object 652 0 (offset 0)
# Ignoring wrong pointing object 655 0 (offset 0)
# Ignoring wrong pointing object 658 0 (offset 0)
# Ignoring wrong pointing object 661 0 (offset 0)
# Ignoring wrong pointing object 664 0 (offset 0)
# Ignoring wrong pointing object 668 0 (offset 0)
# Ignoring wrong pointing object 671 0 (offset 0)
# Ignoring wrong pointing object 674 0 (offset 0)
# Ignoring wrong pointing object 677 0 (offset 0)
# Ignoring wrong pointing object 680 0 (offset 0)
# Ignoring wrong pointing object 683 0 (offset 0)
# Ignoring wrong pointing object 686 0 (offset 0)
# Ignoring wrong pointing object 689 0 (offset 0)
# Ignoring wrong pointing object 692 0 (offset 0)
# Ignoring wrong pointing object 695 0 (offset 0)
# Ignoring wrong pointing object 699 0 (offset 0)
# Ignoring wrong pointing object 702 0 (offset 0)
# Ignoring wrong pointing object 705 0 (offset 0)
# Ignoring wrong pointing object 708 0 (offset 0)
# Ignoring wrong pointing object 711 0 (offset 0)
# Ignoring wrong pointing object 714 0 (offset 0)
# Ignoring wrong pointing object 717 0 (offset 0)
# Ignoring wrong pointing object 720 0 (offset 0)
# Ignoring wrong pointing object 723 0 (offset 0)
# Ignoring wrong pointing object 726 0 (offset 0)
# Ignoring wrong pointing object 729 0 (offset 0)
# Ignoring wrong pointing object 733 0 (offset 0)
# Ignoring wrong pointing object 736 0 (offset 0)
# Ignoring wrong pointing object 739 0 (offset 0)
# Ignoring wrong pointing object 742 0 (offset 0)
# Ignoring wrong pointing object 745 0 (offset 0)
# Ignoring wrong pointing object 748 0 (offset 0)
# Ignoring wrong pointing object 751 0 (offset 0)
# Ignoring wrong pointing object 754 0 (offset 0)
# Ignoring wrong pointing object 757 0 (offset 0)
# Ignoring wrong pointing object 760 0 (offset 0)
# Ignoring wrong pointing object 763 0 (offset 0)
# Ignoring wrong pointing object 769 0 (offset 0)
# Ignoring wrong pointing object 774 0 (offset 0)
# Ignoring wrong pointing object 777 0 (offset 0)
# Ignoring wrong pointing object 780 0 (offset 0)
# Ignoring wrong pointing object 784 0 (offset 0)
# Ignoring wrong pointing object 787 0 (offset 0)
# Ignoring wrong pointing object 790 0 (offset 0)
# Ignoring wrong pointing object 793 0 (offset 0)
# Ignoring wrong pointing object 796 0 (offset 0)
# Ignoring wrong pointing object 799 0 (offset 0)
# Ignoring wrong pointing object 802 0 (offset 0)
# Ignoring wrong pointing object 805 0 (offset 0)
# Ignoring wrong pointing object 808 0 (offset 0)
# Ignoring wrong pointing object 811 0 (offset 0)
# Ignoring wrong pointing object 816 0 (offset 0)
# Ignoring wrong pointing object 819 0 (offset 0)
# Ignoring wrong pointing object 822 0 (offset 0)
# Ignoring wrong pointing object 825 0 (offset 0)
# Ignoring wrong pointing object 828 0 (offset 0)
# Ignoring wrong pointing object 831 0 (offset 0)
# Ignoring wrong pointing object 834 0 (offset 0)
# Ignoring wrong pointing object 838 0 (offset 0)
# Ignoring wrong pointing object 841 0 (offset 0)
# Ignoring wrong pointing object 844 0 (offset 0)
# Ignoring wrong pointing object 847 0 (offset 0)
# Ignoring wrong pointing object 850 0 (offset 0)
# Ignoring wrong pointing object 853 0 (offset 0)
# Ignoring wrong pointing object 856 0 (offset 0)
# Ignoring wrong pointing object 859 0 (offset 0)
# Ignoring wrong pointing object 862 0 (offset 0)
# Ignoring wrong pointing object 865 0 (offset 0)
# Ignoring wrong pointing object 868 0 (offset 0)
# Ignoring wrong pointing object 871 0 (offset 0)
# Ignoring wrong pointing object 874 0 (offset 0)
# Ignoring wrong pointing object 877 0 (offset 0)
# Ignoring wrong pointing object 880 0 (offset 0)
# Ignoring wrong pointing object 883 0 (offset 0)
# Ignoring wrong pointing object 886 0 (offset 0)
# Ignoring wrong pointing object 891 0 (offset 0)
# Ignoring wrong pointing object 894 0 (offset 0)
# Ignoring wrong pointing object 897 0 (offset 0)
# Ignoring wrong pointing object 900 0 (offset 0)
# Ignoring wrong pointing object 903 0 (offset 0)
# Ignoring wrong pointing object 906 0 (offset 0)
# Ignoring wrong pointing object 910 0 (offset 0)
# Ignoring wrong pointing object 913 0 (offset 0)
# Ignoring wrong pointing object 916 0 (offset 0)
# Ignoring wrong pointing object 919 0 (offset 0)
# Ignoring wrong pointing object 922 0 (offset 0)
# Ignoring wrong pointing object 925 0 (offset 0)
# Ignoring wrong pointing object 928 0 (offset 0)
# Ignoring wrong pointing object 931 0 (offset 0)
# Ignoring wrong pointing object 934 0 (offset 0)
# Ignoring wrong pointing object 937 0 (offset 0)
# Ignoring wrong pointing object 940 0 (offset 0)
# Ignoring wrong pointing object 943 0 (offset 0)
# Ignoring wrong pointing object 946 0 (offset 0)
# Ignoring wrong pointing object 949 0 (offset 0)
# Ignoring wrong pointing object 952 0 (offset 0)
# Ignoring wrong pointing object 955 0 (offset 0)
# Ignoring wrong pointing object 959 0 (offset 0)
# Ignoring wrong pointing object 962 0 (offset 0)
# Ignoring wrong pointing object 965 0 (offset 0)
# Ignoring wrong pointing object 968 0 (offset 0)
# Ignoring wrong pointing object 971 0 (offset 0)
# Ignoring wrong pointing object 974 0 (offset 0)
# Ignoring wrong pointing object 977 0 (offset 0)
# Ignoring wrong pointing object 980 0 (offset 0)
# Ignoring wrong pointing object 983 0 (offset 0)
# Ignoring wrong pointing object 986 0 (offset 0)
# Ignoring wrong pointing object 989 0 (offset 0)
# Ignoring wrong pointing object 992 0 (offset 0)
# Ignoring wrong pointing object 995 0 (offset 0)
# Ignoring wrong pointing object 998 0 (offset 0)
# Ignoring wrong pointing object 1001 0 (offset 0)
# Ignoring wrong pointing object 1004 0 (offset 0)
# Ignoring wrong pointing object 1007 0 (offset 0)
# Ignoring wrong pointing object 1010 0 (offset 0)
# Ignoring wrong pointing object 1013 0 (offset 0)
# Ignoring wrong pointing object 1016 0 (offset 0)
# Ignoring wrong pointing object 1019 0 (offset 0)
# Ignoring wrong pointing object 1022 0 (offset 0)
# Ignoring wrong pointing object 1026 0 (offset 0)
# Ignoring wrong pointing object 1029 0 (offset 0)
# Ignoring wrong pointing object 1032 0 (offset 0)
# Ignoring wrong pointing object 1035 0 (offset 0)
# Ignoring wrong pointing object 1038 0 (offset 0)
# Ignoring wrong pointing object 1041 0 (offset 0)
# Ignoring wrong pointing object 1044 0 (offset 0)
# Ignoring wrong pointing object 1048 0 (offset 0)
# Ignoring wrong pointing object 1051 0 (offset 0)
# Ignoring wrong pointing object 1055 0 (offset 0)
# Ignoring wrong pointing object 1058 0 (offset 0)
# Ignoring wrong pointing object 1061 0 (offset 0)
# Ignoring wrong pointing object 1064 0 (offset 0)
# Ignoring wrong pointing object 1068 0 (offset 0)
# Ignoring wrong pointing object 1071 0 (offset 0)
# Ignoring wrong pointing object 1074 0 (offset 0)
# Ignoring wrong pointing object 1077 0 (offset 0)
# Ignoring wrong pointing object 1081 0 (offset 0)
# Ignoring wrong pointing object 1084 0 (offset 0)
# Ignoring wrong pointing object 1088 0 (offset 0)
# Ignoring wrong pointing object 1091 0 (offset 0)
# Ignoring wrong pointing object 1094 0 (offset 0)
# Ignoring wrong pointing object 1097 0 (offset 0)
# Ignoring wrong pointing object 1100 0 (offset 0)
# Ignoring wrong pointing object 1103 0 (offset 0)
# Ignoring wrong pointing object 1106 0 (offset 0)
# Ignoring wrong pointing object 1110 0 (offset 0)
# Ignoring wrong pointing object 1114 0 (offset 0)
# Ignoring wrong pointing object 1117 0 (offset 0)
# Ignoring wrong pointing object 1120 0 (offset 0)
# Ignoring wrong pointing object 1123 0 (offset 0)
# Ignoring wrong pointing object 1126 0 (offset 0)
# Ignoring wrong pointing object 1129 0 (offset 0)
# Ignoring wrong pointing object 1132 0 (offset 0)
# Ignoring wrong pointing object 1135 0 (offset 0)
# Ignoring wrong pointing object 1138 0 (offset 0)
# Ignoring wrong pointing object 1141 0 (offset 0)
# Ignoring wrong pointing object 1144 0 (offset 0)
# Ignoring wrong pointing object 1147 0 (offset 0)
# Ignoring wrong pointing object 1148 0 (offset 0)
# Ignoring wrong pointing object 1149 0 (offset 0)
# Ignoring wrong pointing object 1150 0 (offset 0)
# Ignoring wrong pointing object 1151 0 (offset 0)
# Ignoring wrong pointing object 1152 0 (offset 0)
# Ignoring wrong pointing object 1153 0 (offset 0)
# Ignoring wrong pointing object 1181 0 (offset 0)
# Ignoring wrong pointing object 1676 0 (offset 0)
# Ignoring wrong pointing object 1679 0 (offset 0)
# Ignoring wrong pointing object 1682 0 (offset 0)
# Ignoring wrong pointing object 1685 0 (offset 0)
# Ignoring wrong pointing object 1688 0 (offset 0)
# Ignoring wrong pointing object 1691 0 (offset 0)
# Ignoring wrong pointing object 1695 0 (offset 0)
# Ignoring wrong pointing object 1698 0 (offset 0)
# Ignoring wrong pointing object 1701 0 (offset 0)
# Ignoring wrong pointing object 1704 0 (offset 0)
# Ignoring wrong pointing object 1707 0 (offset 0)
# Ignoring wrong pointing object 1710 0 (offset 0)
# Ignoring wrong pointing object 1713 0 (offset 0)
# Ignoring wrong pointing object 1716 0 (offset 0)
# Ignoring wrong pointing object 1719 0 (offset 0)
# Ignoring wrong pointing object 1722 0 (offset 0)
# Ignoring wrong pointing object 1726 0 (offset 0)
# Ignoring wrong pointing object 1729 0 (offset 0)
# Ignoring wrong pointing object 1732 0 (offset 0)
# Ignoring wrong pointing object 1735 0 (offset 0)
# Ignoring wrong pointing object 1738 0 (offset 0)
# Ignoring wrong pointing object 1741 0 (offset 0)
# Ignoring wrong pointing object 1744 0 (offset 0)
# Ignoring wrong pointing object 1747 0 (offset 0)
# Ignoring wrong pointing object 1750 0 (offset 0)
# Ignoring wrong pointing object 1753 0 (offset 0)
# Ignoring wrong pointing object 1756 0 (offset 0)
# Ignoring wrong pointing object 1759 0 (offset 0)
# Ignoring wrong pointing object 1763 0 (offset 0)
# Ignoring wrong pointing object 1766 0 (offset 0)
# Ignoring wrong pointing object 1769 0 (offset 0)
# Ignoring wrong pointing object 1772 0 (offset 0)
# Ignoring wrong pointing object 1775 0 (offset 0)
# Ignoring wrong pointing object 1778 0 (offset 0)
# Ignoring wrong pointing object 1781 0 (offset 0)
# Ignoring wrong pointing object 1784 0 (offset 0)
# Ignoring wrong pointing object 1787 0 (offset 0)
# Ignoring wrong pointing object 1790 0 (offset 0)
# Ignoring wrong pointing object 1793 0 (offset 0)
# Ignoring wrong pointing object 1796 0 (offset 0)
# Ignoring wrong pointing object 1799 0 (offset 0)
# Ignoring wrong pointing object 1802 0 (offset 0)
# Ignoring wrong pointing object 1805 0 (offset 0)
# Ignoring wrong pointing object 1808 0 (offset 0)
# Ignoring wrong pointing object 1811 0 (offset 0)
# Ignoring wrong pointing object 1814 0 (offset 0)
# Ignoring wrong pointing object 1817 0 (offset 0)
# Ignoring wrong pointing object 1821 0 (offset 0)
# Ignoring wrong pointing object 1824 0 (offset 0)
# Ignoring wrong pointing object 1827 0 (offset 0)
# Ignoring wrong pointing object 1830 0 (offset 0)
# Ignoring wrong pointing object 1833 0 (offset 0)
# Ignoring wrong pointing object 1837 0 (offset 0)
# Ignoring wrong pointing object 1840 0 (offset 0)
# Ignoring wrong pointing object 1843 0 (offset 0)
# Ignoring wrong pointing object 1846 0 (offset 0)
# Ignoring wrong pointing object 1849 0 (offset 0)
# Ignoring wrong pointing object 1852 0 (offset 0)
# Ignoring wrong pointing object 1855 0 (offset 0)
# Ignoring wrong pointing object 1858 0 (offset 0)
# Ignoring wrong pointing object 1861 0 (offset 0)
# Ignoring wrong pointing object 1864 0 (offset 0)
# Ignoring wrong pointing object 1867 0 (offset 0)
# Ignoring wrong pointing object 1871 0 (offset 0)
# Ignoring wrong pointing object 1874 0 (offset 0)
# Ignoring wrong pointing object 1877 0 (offset 0)
# Ignoring wrong pointing object 1880 0 (offset 0)
# Ignoring wrong pointing object 1883 0 (offset 0)
# Ignoring wrong pointing object 1886 0 (offset 0)
# Ignoring wrong pointing object 1889 0 (offset 0)
# Ignoring wrong pointing object 1893 0 (offset 0)
# Ignoring wrong pointing object 1896 0 (offset 0)
# Ignoring wrong pointing object 1899 0 (offset 0)
# Ignoring wrong pointing object 1902 0 (offset 0)
# Ignoring wrong pointing object 1905 0 (offset 0)
# Ignoring wrong pointing object 1908 0 (offset 0)
# Ignoring wrong pointing object 1911 0 (offset 0)
# Ignoring wrong pointing object 1914 0 (offset 0)
# Ignoring wrong pointing object 1917 0 (offset 0)
# Ignoring wrong pointing object 1920 0 (offset 0)
# Ignoring wrong pointing object 1923 0 (offset 0)
# Ignoring wrong pointing object 1926 0 (offset 0)
# Ignoring wrong pointing object 1929 0 (offset 0)
# Ignoring wrong pointing object 1932 0 (offset 0)
# Ignoring wrong pointing object 1936 0 (offset 0)
# Ignoring wrong pointing object 1939 0 (offset 0)
# Ignoring wrong pointing object 1942 0 (offset 0)
# Ignoring wrong pointing object 1945 0 (offset 0)
# Ignoring wrong pointing object 1948 0 (offset 0)
# Ignoring wrong pointing object 1951 0 (offset 0)
# Ignoring wrong pointing object 1954 0 (offset 0)
# Ignoring wrong pointing object 1957 0 (offset 0)
# Ignoring wrong pointing object 1960 0 (offset 0)
# Ignoring wrong pointing object 1963 0 (offset 0)
# Ignoring wrong pointing object 1966 0 (offset 0)
# Ignoring wrong pointing object 1969 0 (offset 0)
# Ignoring wrong pointing object 1972 0 (offset 0)
# Ignoring wrong pointing object 1975 0 (offset 0)
# Ignoring wrong pointing object 1978 0 (offset 0)
# Ignoring wrong pointing object 1981 0 (offset 0)
# Ignoring wrong pointing object 1984 0 (offset 0)
# Ignoring wrong pointing object 1987 0 (offset 0)
# Ignoring wrong pointing object 1991 0 (offset 0)
# Ignoring wrong pointing object 1994 0 (offset 0)
# Ignoring wrong pointing object 1997 0 (offset 0)
# Ignoring wrong pointing object 2000 0 (offset 0)
# Ignoring wrong pointing object 2004 0 (offset 0)
# Ignoring wrong pointing object 2007 0 (offset 0)
# Ignoring wrong pointing object 2010 0 (offset 0)
# Ignoring wrong pointing object 2013 0 (offset 0)
# Ignoring wrong pointing object 2016 0 (offset 0)
# Ignoring wrong pointing object 2019 0 (offset 0)
# Ignoring wrong pointing object 2022 0 (offset 0)
# Ignoring wrong pointing object 2025 0 (offset 0)
# Ignoring wrong pointing object 2028 0 (offset 0)
# Ignoring wrong pointing object 2031 0 (offset 0)
# Ignoring wrong pointing object 2034 0 (offset 0)
# Ignoring wrong pointing object 2037 0 (offset 0)
# Ignoring wrong pointing object 2040 0 (offset 0)
# Ignoring wrong pointing object 2043 0 (offset 0)
# Ignoring wrong pointing object 2046 0 (offset 0)
# Ignoring wrong pointing object 2049 0 (offset 0)
# Ignoring wrong pointing object 2052 0 (offset 0)
# Ignoring wrong pointing object 2055 0 (offset 0)
# Ignoring wrong pointing object 2058 0 (offset 0)
# Ignoring wrong pointing object 2061 0 (offset 0)
# Ignoring wrong pointing object 2064 0 (offset 0)
# Ignoring wrong pointing object 2067 0 (offset 0)
# Ignoring wrong pointing object 2070 0 (offset 0)
# Ignoring wrong pointing object 2073 0 (offset 0)
# Ignoring wrong pointing object 2077 0 (offset 0)
# Ignoring wrong pointing object 2080 0 (offset 0)
# Ignoring wrong pointing object 2083 0 (offset 0)
# Ignoring wrong pointing object 2086 0 (offset 0)
# Ignoring wrong pointing object 2089 0 (offset 0)
# Ignoring wrong pointing object 2092 0 (offset 0)
# Ignoring wrong pointing object 2095 0 (offset 0)
# Ignoring wrong pointing object 2098 0 (offset 0)
# Ignoring wrong pointing object 2101 0 (offset 0)
# Ignoring wrong pointing object 2104 0 (offset 0)
# Ignoring wrong pointing object 2107 0 (offset 0)
# Ignoring wrong pointing object 2111 0 (offset 0)
# Ignoring wrong pointing object 2114 0 (offset 0)
# Ignoring wrong pointing object 2117 0 (offset 0)
# Ignoring wrong pointing object 2120 0 (offset 0)
# Ignoring wrong pointing object 2123 0 (offset 0)
# Ignoring wrong pointing object 2126 0 (offset 0)
# Ignoring wrong pointing object 2129 0 (offset 0)
# Ignoring wrong pointing object 2132 0 (offset 0)
# Ignoring wrong pointing object 2135 0 (offset 0)
# Ignoring wrong pointing object 2138 0 (offset 0)
# Ignoring wrong pointing object 2141 0 (offset 0)
# Ignoring wrong pointing object 2144 0 (offset 0)
# Ignoring wrong pointing object 2147 0 (offset 0)
# Ignoring wrong pointing object 2150 0 (offset 0)
# Ignoring wrong pointing object 2153 0 (offset 0)
# Ignoring wrong pointing object 2156 0 (offset 0)
# Ignoring wrong pointing object 2160 0 (offset 0)
# Ignoring wrong pointing object 2163 0 (offset 0)
# Ignoring wrong pointing object 2166 0 (offset 0)
# Ignoring wrong pointing object 2169 0 (offset 0)
# Ignoring wrong pointing object 2172 0 (offset 0)
# Ignoring wrong pointing object 2175 0 (offset 0)
# Ignoring wrong pointing object 2178 0 (offset 0)
# Ignoring wrong pointing object 2181 0 (offset 0)
# Ignoring wrong pointing object 2184 0 (offset 0)
# Ignoring wrong pointing object 2187 0 (offset 0)
# Ignoring wrong pointing object 2190 0 (offset 0)
# Ignoring wrong pointing object 2193 0 (offset 0)
# Ignoring wrong pointing object 2196 0 (offset 0)
# Ignoring wrong pointing object 2199 0 (offset 0)
# Ignoring wrong pointing object 2202 0 (offset 0)
# Ignoring wrong pointing object 2205 0 (offset 0)
# Ignoring wrong pointing object 2208 0 (offset 0)
# Ignoring wrong pointing object 2211 0 (offset 0)
# Ignoring wrong pointing object 2214 0 (offset 0)
# Ignoring wrong pointing object 2217 0 (offset 0)
# Ignoring wrong pointing object 2220 0 (offset 0)
# Ignoring wrong pointing object 2223 0 (offset 0)
# Ignoring wrong pointing object 2226 0 (offset 0)
# Ignoring wrong pointing object 2230 0 (offset 0)
# Ignoring wrong pointing object 2233 0 (offset 0)
# Ignoring wrong pointing object 2236 0 (offset 0)
# Ignoring wrong pointing object 2239 0 (offset 0)
# Ignoring wrong pointing object 2242 0 (offset 0)
# Ignoring wrong pointing object 2245 0 (offset 0)
# Ignoring wrong pointing object 2248 0 (offset 0)
# Ignoring wrong pointing object 2251 0 (offset 0)
# Ignoring wrong pointing object 2254 0 (offset 0)
# Ignoring wrong pointing object 2257 0 (offset 0)
# Ignoring wrong pointing object 2260 0 (offset 0)
# Ignoring wrong pointing object 2263 0 (offset 0)
# Ignoring wrong pointing object 2266 0 (offset 0)
# Ignoring wrong pointing object 2269 0 (offset 0)
# Ignoring wrong pointing object 2272 0 (offset 0)
# Ignoring wrong pointing object 2275 0 (offset 0)
# Ignoring wrong pointing object 2279 0 (offset 0)
# Ignoring wrong pointing object 2283 0 (offset 0)
# Ignoring wrong pointing object 2286 0 (offset 0)
# Ignoring wrong pointing object 2289 0 (offset 0)
# Ignoring wrong pointing object 2292 0 (offset 0)
# Ignoring wrong pointing object 2295 0 (offset 0)
# Ignoring wrong pointing object 2298 0 (offset 0)
# Ignoring wrong pointing object 2301 0 (offset 0)
# Ignoring wrong pointing object 2306 0 (offset 0)
# Ignoring wrong pointing object 2310 0 (offset 0)
# Ignoring wrong pointing object 2313 0 (offset 0)
# Ignoring wrong pointing object 2316 0 (offset 0)
# Ignoring wrong pointing object 2319 0 (offset 0)
# Ignoring wrong pointing object 2322 0 (offset 0)
# Ignoring wrong pointing object 2325 0 (offset 0)
# Ignoring wrong pointing object 2328 0 (offset 0)
# Ignoring wrong pointing object 2331 0 (offset 0)
# Ignoring wrong pointing object 2335 0 (offset 0)
# Ignoring wrong pointing object 2338 0 (offset 0)
# Ignoring wrong pointing object 2341 0 (offset 0)
# Ignoring wrong pointing object 2344 0 (offset 0)
# Ignoring wrong pointing object 2348 0 (offset 0)
# Ignoring wrong pointing object 2352 0 (offset 0)
# Ignoring wrong pointing object 2355 0 (offset 0)
# Ignoring wrong pointing object 2358 0 (offset 0)
# Ignoring wrong pointing object 2361 0 (offset 0)
# Ignoring wrong pointing object 2364 0 (offset 0)
# Ignoring wrong pointing object 2367 0 (offset 0)
# Ignoring wrong pointing object 2370 0 (offset 0)
# Ignoring wrong pointing object 2373 0 (offset 0)
# Ignoring wrong pointing object 2376 0 (offset 0)
# Ignoring wrong pointing object 2379 0 (offset 0)
# Ignoring wrong pointing object 2382 0 (offset 0)
# Ignoring wrong pointing object 2385 0 (offset 0)
# Ignoring wrong pointing object 2388 0 (offset 0)
# Ignoring wrong pointing object 2391 0 (offset 0)
# Ignoring wrong pointing object 2394 0 (offset 0)
# Ignoring wrong pointing object 2397 0 (offset 0)
# Ignoring wrong pointing object 2400 0 (offset 0)
# Ignoring wrong pointing object 2403 0 (offset 0)
# Ignoring wrong pointing object 2406 0 (offset 0)
# Ignoring wrong pointing object 2409 0 (offset 0)
# Ignoring wrong pointing object 2413 0 (offset 0)
# Ignoring wrong pointing object 2416 0 (offset 0)
# Ignoring wrong pointing object 2419 0 (offset 0)
# Ignoring wrong pointing object 2422 0 (offset 0)
# Ignoring wrong pointing object 2425 0 (offset 0)
# Ignoring wrong pointing object 2428 0 (offset 0)
# Ignoring wrong pointing object 2431 0 (offset 0)
# Ignoring wrong pointing object 2434 0 (offset 0)
# Ignoring wrong pointing object 2437 0 (offset 0)
# Ignoring wrong pointing object 2440 0 (offset 0)
# Ignoring wrong pointing object 2443 0 (offset 0)
# Ignoring wrong pointing object 2446 0 (offset 0)
# Ignoring wrong pointing object 2449 0 (offset 0)
# Ignoring wrong pointing object 2452 0 (offset 0)
# Ignoring wrong pointing object 2455 0 (offset 0)
# Ignoring wrong pointing object 2458 0 (offset 0)
# Ignoring wrong pointing object 2461 0 (offset 0)
# Ignoring wrong pointing object 2464 0 (offset 0)
# Ignoring wrong pointing object 2467 0 (offset 0)
# Ignoring wrong pointing object 2470 0 (offset 0)
# Ignoring wrong pointing object 2473 0 (offset 0)
# Ignoring wrong pointing object 2477 0 (offset 0)
# Ignoring wrong pointing object 2480 0 (offset 0)
# Ignoring wrong pointing object 2483 0 (offset 0)
# Ignoring wrong pointing object 2486 0 (offset 0)
# Ignoring wrong pointing object 2489 0 (offset 0)
# Ignoring wrong pointing object 2492 0 (offset 0)
# Ignoring wrong pointing object 2495 0 (offset 0)
# Ignoring wrong pointing object 2498 0 (offset 0)
# Ignoring wrong pointing object 2501 0 (offset 0)
# Ignoring wrong pointing object 2504 0 (offset 0)
# Ignoring wrong pointing object 2507 0 (offset 0)
# Ignoring wrong pointing object 2510 0 (offset 0)
# Ignoring wrong pointing object 2513 0 (offset 0)
# Ignoring wrong pointing object 2516 0 (offset 0)
# Ignoring wrong pointing object 2519 0 (offset 0)
# Ignoring wrong pointing object 2522 0 (offset 0)
# Ignoring wrong pointing object 2525 0 (offset 0)
# Ignoring wrong pointing object 2528 0 (offset 0)
# Ignoring wrong pointing object 2531 0 (offset 0)
# Ignoring wrong pointing object 2534 0 (offset 0)
# Ignoring wrong pointing object 2537 0 (offset 0)
# Ignoring wrong pointing object 2540 0 (offset 0)
# Ignoring wrong pointing object 2543 0 (offset 0)
# Ignoring wrong pointing object 2546 0 (offset 0)
# Ignoring wrong pointing object 2549 0 (offset 0)
# Ignoring wrong pointing object 2552 0 (offset 0)
# Ignoring wrong pointing object 2555 0 (offset 0)
# Ignoring wrong pointing object 2558 0 (offset 0)
# Ignoring wrong pointing object 2561 0 (offset 0)
# Ignoring wrong pointing object 2565 0 (offset 0)
# Ignoring wrong pointing object 2568 0 (offset 0)
# Ignoring wrong pointing object 2571 0 (offset 0)
# Ignoring wrong pointing object 2574 0 (offset 0)
# Ignoring wrong pointing object 2577 0 (offset 0)
# Ignoring wrong pointing object 2580 0 (offset 0)
# Ignoring wrong pointing object 2583 0 (offset 0)
# Ignoring wrong pointing object 2586 0 (offset 0)
# Ignoring wrong pointing object 2589 0 (offset 0)
# Ignoring wrong pointing object 2592 0 (offset 0)
# Ignoring wrong pointing object 2595 0 (offset 0)
# Ignoring wrong pointing object 2598 0 (offset 0)
# Ignoring wrong pointing object 2601 0 (offset 0)
# Ignoring wrong pointing object 2604 0 (offset 0)
# Ignoring wrong pointing object 2607 0 (offset 0)
# Ignoring wrong pointing object 2610 0 (offset 0)
# Ignoring wrong pointing object 2613 0 (offset 0)
# Ignoring wrong pointing object 2616 0 (offset 0)
# Ignoring wrong pointing object 2619 0 (offset 0)
# Ignoring wrong pointing object 2622 0 (offset 0)
# Ignoring wrong pointing object 2625 0 (offset 0)
# Ignoring wrong pointing object 2628 0 (offset 0)
# Ignoring wrong pointing object 2631 0 (offset 0)
# Ignoring wrong pointing object 2634 0 (offset 0)
# Ignoring wrong pointing object 2637 0 (offset 0)
# Ignoring wrong pointing object 2641 0 (offset 0)
# Ignoring wrong pointing object 2644 0 (offset 0)
# Ignoring wrong pointing object 2647 0 (offset 0)
# Ignoring wrong pointing object 2650 0 (offset 0)
# Ignoring wrong pointing object 2653 0 (offset 0)
# Ignoring wrong pointing object 2656 0 (offset 0)
# Ignoring wrong pointing object 2659 0 (offset 0)
# Ignoring wrong pointing object 2662 0 (offset 0)
# Ignoring wrong pointing object 2665 0 (offset 0)
# Ignoring wrong pointing object 2668 0 (offset 0)
# Ignoring wrong pointing object 2671 0 (offset 0)
# Ignoring wrong pointing object 2674 0 (offset 0)
# Ignoring wrong pointing object 2677 0 (offset 0)
# Ignoring wrong pointing object 2680 0 (offset 0)
# Ignoring wrong pointing object 2683 0 (offset 0)
# Ignoring wrong pointing object 2686 0 (offset 0)
# Ignoring wrong pointing object 2689 0 (offset 0)
# Ignoring wrong pointing object 2692 0 (offset 0)
# Ignoring wrong pointing object 2695 0 (offset 0)
# Ignoring wrong pointing object 2698 0 (offset 0)
# Ignoring wrong pointing object 2701 0 (offset 0)
# Ignoring wrong pointing object 2705 0 (offset 0)
# Ignoring wrong pointing object 2708 0 (offset 0)
# Ignoring wrong pointing object 2711 0 (offset 0)
# Ignoring wrong pointing object 2714 0 (offset 0)
# Ignoring wrong pointing object 2717 0 (offset 0)
# Ignoring wrong pointing object 2720 0 (offset 0)
# Ignoring wrong pointing object 2723 0 (offset 0)
# Ignoring wrong pointing object 2726 0 (offset 0)
# Ignoring wrong pointing object 2729 0 (offset 0)
# Ignoring wrong pointing object 2732 0 (offset 0)
# Ignoring wrong pointing object 2735 0 (offset 0)
# Ignoring wrong pointing object 2738 0 (offset 0)
# Ignoring wrong pointing object 2741 0 (offset 0)
# Ignoring wrong pointing object 2744 0 (offset 0)
# Ignoring wrong pointing object 2747 0 (offset 0)
# Ignoring wrong pointing object 2750 0 (offset 0)
# Ignoring wrong pointing object 2754 0 (offset 0)
# Ignoring wrong pointing object 2757 0 (offset 0)
# Ignoring wrong pointing object 2760 0 (offset 0)
# Ignoring wrong pointing object 2763 0 (offset 0)
# Ignoring wrong pointing object 2766 0 (offset 0)
# Ignoring wrong pointing object 2769 0 (offset 0)
# Ignoring wrong pointing object 2772 0 (offset 0)
# Ignoring wrong pointing object 2775 0 (offset 0)
# Ignoring wrong pointing object 2778 0 (offset 0)
# Ignoring wrong pointing object 2781 0 (offset 0)
# Ignoring wrong pointing object 2784 0 (offset 0)
# Ignoring wrong pointing object 2787 0 (offset 0)
# Ignoring wrong pointing object 2790 0 (offset 0)
# Ignoring wrong pointing object 2793 0 (offset 0)
# Ignoring wrong pointing object 2796 0 (offset 0)
# Ignoring wrong pointing object 2800 0 (offset 0)
# Ignoring wrong pointing object 2803 0 (offset 0)
# Ignoring wrong pointing object 2806 0 (offset 0)
# Ignoring wrong pointing object 2809 0 (offset 0)
# Ignoring wrong pointing object 2812 0 (offset 0)
# Ignoring wrong pointing object 2815 0 (offset 0)
# Ignoring wrong pointing object 2818 0 (offset 0)
# Ignoring wrong pointing object 2821 0 (offset 0)
# Ignoring wrong pointing object 2824 0 (offset 0)
# Ignoring wrong pointing object 2827 0 (offset 0)
# Ignoring wrong pointing object 2830 0 (offset 0)
# Ignoring wrong pointing object 2833 0 (offset 0)
# Ignoring wrong pointing object 2836 0 (offset 0)
# Ignoring wrong pointing object 2839 0 (offset 0)
# Ignoring wrong pointing object 2842 0 (offset 0)
# Ignoring wrong pointing object 2845 0 (offset 0)
# Ignoring wrong pointing object 2848 0 (offset 0)
# Ignoring wrong pointing object 2851 0 (offset 0)
# Ignoring wrong pointing object 2854 0 (offset 0)
# Ignoring wrong pointing object 2857 0 (offset 0)
# Ignoring wrong pointing object 2860 0 (offset 0)
# Ignoring wrong pointing object 2863 0 (offset 0)
# Ignoring wrong pointing object 2866 0 (offset 0)
# Ignoring wrong pointing object 2869 0 (offset 0)
# Ignoring wrong pointing object 2872 0 (offset 0)
# Ignoring wrong pointing object 2875 0 (offset 0)
# Ignoring wrong pointing object 2879 0 (offset 0)
# Ignoring wrong pointing object 2882 0 (offset 0)
# Ignoring wrong pointing object 2885 0 (offset 0)
# Ignoring wrong pointing object 2888 0 (offset 0)
# Ignoring wrong pointing object 2891 0 (offset 0)
# Ignoring wrong pointing object 2894 0 (offset 0)
# Ignoring wrong pointing object 2897 0 (offset 0)
# Ignoring wrong pointing object 2900 0 (offset 0)
# Ignoring wrong pointing object 2903 0 (offset 0)
# Ignoring wrong pointing object 2906 0 (offset 0)
# Ignoring wrong pointing object 2909 0 (offset 0)
# Ignoring wrong pointing object 2912 0 (offset 0)
# Ignoring wrong pointing object 2916 0 (offset 0)
# Ignoring wrong pointing object 2919 0 (offset 0)
# Ignoring wrong pointing object 2922 0 (offset 0)
# Ignoring wrong pointing object 2925 0 (offset 0)
# Ignoring wrong pointing object 2928 0 (offset 0)
# Ignoring wrong pointing object 2931 0 (offset 0)
# Ignoring wrong pointing object 2934 0 (offset 0)
# Ignoring wrong pointing object 2937 0 (offset 0)
# Ignoring wrong pointing object 2940 0 (offset 0)
# Ignoring wrong pointing object 2943 0 (offset 0)
# Ignoring wrong pointing object 2946 0 (offset 0)
# Ignoring wrong pointing object 2949 0 (offset 0)
# Ignoring wrong pointing object 2952 0 (offset 0)
# Ignoring wrong pointing object 2956 0 (offset 0)
# Ignoring wrong pointing object 2959 0 (offset 0)
# Ignoring wrong pointing object 2962 0 (offset 0)
# Ignoring wrong pointing object 2965 0 (offset 0)
# Ignoring wrong pointing object 2968 0 (offset 0)
# Ignoring wrong pointing object 2971 0 (offset 0)
# Ignoring wrong pointing object 2974 0 (offset 0)
# Ignoring wrong pointing object 2977 0 (offset 0)
# Ignoring wrong pointing object 2980 0 (offset 0)
# Ignoring wrong pointing object 2983 0 (offset 0)
# Ignoring wrong pointing object 2986 0 (offset 0)
# Ignoring wrong pointing object 2989 0 (offset 0)
# Ignoring wrong pointing object 2992 0 (offset 0)
# Ignoring wrong pointing object 2995 0 (offset 0)
# Ignoring wrong pointing object 2998 0 (offset 0)
# Ignoring wrong pointing object 3002 0 (offset 0)
# Ignoring wrong pointing object 3005 0 (offset 0)
# Ignoring wrong pointing object 3008 0 (offset 0)
# Ignoring wrong pointing object 3011 0 (offset 0)
# Ignoring wrong pointing object 3014 0 (offset 0)
# Ignoring wrong pointing object 3018 0 (offset 0)
# Ignoring wrong pointing object 3021 0 (offset 0)
# Ignoring wrong pointing object 3024 0 (offset 0)
# Ignoring wrong pointing object 3027 0 (offset 0)
# Ignoring wrong pointing object 3030 0 (offset 0)
# Ignoring wrong pointing object 3033 0 (offset 0)
# Ignoring wrong pointing object 3036 0 (offset 0)
# Ignoring wrong pointing object 3039 0 (offset 0)
# Ignoring wrong pointing object 3042 0 (offset 0)
# Ignoring wrong pointing object 3045 0 (offset 0)
# Ignoring wrong pointing object 3048 0 (offset 0)
# Ignoring wrong pointing object 3051 0 (offset 0)
# Ignoring wrong pointing object 3055 0 (offset 0)
# Ignoring wrong pointing object 3058 0 (offset 0)
# Ignoring wrong pointing object 3061 0 (offset 0)
# Ignoring wrong pointing object 3064 0 (offset 0)
# Ignoring wrong pointing object 3067 0 (offset 0)
# Ignoring wrong pointing object 3070 0 (offset 0)
# Ignoring wrong pointing object 3073 0 (offset 0)
# Ignoring wrong pointing object 3076 0 (offset 0)
# Ignoring wrong pointing object 3079 0 (offset 0)
# Ignoring wrong pointing object 3082 0 (offset 0)
# Ignoring wrong pointing object 3085 0 (offset 0)
# Ignoring wrong pointing object 3088 0 (offset 0)
# Ignoring wrong pointing object 3091 0 (offset 0)
# Ignoring wrong pointing object 3094 0 (offset 0)
# Ignoring wrong pointing object 3097 0 (offset 0)
# Ignoring wrong pointing object 3101 0 (offset 0)
# Ignoring wrong pointing object 3104 0 (offset 0)
# Ignoring wrong pointing object 3107 0 (offset 0)
# Ignoring wrong pointing object 3110 0 (offset 0)
# Ignoring wrong pointing object 3113 0 (offset 0)
# Ignoring wrong pointing object 3116 0 (offset 0)
# Ignoring wrong pointing object 3119 0 (offset 0)
# Ignoring wrong pointing object 3122 0 (offset 0)
# Ignoring wrong pointing object 3125 0 (offset 0)
# Ignoring wrong pointing object 3128 0 (offset 0)
# Ignoring wrong pointing object 3131 0 (offset 0)
# Ignoring wrong pointing object 3134 0 (offset 0)
# Ignoring wrong pointing object 3137 0 (offset 0)
# Ignoring wrong pointing object 3140 0 (offset 0)
# Ignoring wrong pointing object 3143 0 (offset 0)
# Ignoring wrong pointing object 3146 0 (offset 0)
# Ignoring wrong pointing object 3149 0 (offset 0)
# Ignoring wrong pointing object 3152 0 (offset 0)
# Ignoring wrong pointing object 3155 0 (offset 0)
# Ignoring wrong pointing object 3158 0 (offset 0)
# Ignoring wrong pointing object 3161 0 (offset 0)
# Ignoring wrong pointing object 3164 0 (offset 0)
# Ignoring wrong pointing object 3167 0 (offset 0)
# Ignoring wrong pointing object 3170 0 (offset 0)
# Ignoring wrong pointing object 3173 0 (offset 0)
# Ignoring wrong pointing object 3176 0 (offset 0)
# Ignoring wrong pointing object 3180 0 (offset 0)
# Ignoring wrong pointing object 3184 0 (offset 0)
# Ignoring wrong pointing object 3187 0 (offset 0)
# Ignoring wrong pointing object 3190 0 (offset 0)
# Ignoring wrong pointing object 3193 0 (offset 0)
# Ignoring wrong pointing object 3196 0 (offset 0)
# Ignoring wrong pointing object 3199 0 (offset 0)
# Ignoring wrong pointing object 3202 0 (offset 0)
# Ignoring wrong pointing object 3205 0 (offset 0)
# Ignoring wrong pointing object 3208 0 (offset 0)
# Ignoring wrong pointing object 3211 0 (offset 0)
# Ignoring wrong pointing object 3214 0 (offset 0)
# Ignoring wrong pointing object 3217 0 (offset 0)
# Ignoring wrong pointing object 3220 0 (offset 0)
# Ignoring wrong pointing object 3223 0 (offset 0)
# Ignoring wrong pointing object 3227 0 (offset 0)
# Ignoring wrong pointing object 3230 0 (offset 0)
# Ignoring wrong pointing object 3233 0 (offset 0)
# Ignoring wrong pointing object 3236 0 (offset 0)
# Ignoring wrong pointing object 3239 0 (offset 0)
# Ignoring wrong pointing object 3242 0 (offset 0)
# Ignoring wrong pointing object 3245 0 (offset 0)
# Ignoring wrong pointing object 3248 0 (offset 0)
# Ignoring wrong pointing object 3251 0 (offset 0)
# Ignoring wrong pointing object 3254 0 (offset 0)
# Ignoring wrong pointing object 3257 0 (offset 0)
# Ignoring wrong pointing object 3260 0 (offset 0)
# Ignoring wrong pointing object 3263 0 (offset 0)
# Ignoring wrong pointing object 3266 0 (offset 0)
# Ignoring wrong pointing object 3269 0 (offset 0)
# Ignoring wrong pointing object 3272 0 (offset 0)
# Ignoring wrong pointing object 3275 0 (offset 0)
# Ignoring wrong pointing object 3278 0 (offset 0)
# Ignoring wrong pointing object 3281 0 (offset 0)
# Ignoring wrong pointing object 3284 0 (offset 0)
# Ignoring wrong pointing object 3287 0 (offset 0)
# Ignoring wrong pointing object 3290 0 (offset 0)
# Ignoring wrong pointing object 3293 0 (offset 0)
# Ignoring wrong pointing object 3296 0 (offset 0)
# Ignoring wrong pointing object 3299 0 (offset 0)
# Ignoring wrong pointing object 3302 0 (offset 0)
# Ignoring wrong pointing object 3306 0 (offset 0)
# Ignoring wrong pointing object 3309 0 (offset 0)
# Ignoring wrong pointing object 3312 0 (offset 0)
# Ignoring wrong pointing object 3315 0 (offset 0)
# Ignoring wrong pointing object 3318 0 (offset 0)
# Ignoring wrong pointing object 3321 0 (offset 0)
# Ignoring wrong pointing object 3324 0 (offset 0)
# Ignoring wrong pointing object 3327 0 (offset 0)
# Ignoring wrong pointing object 3330 0 (offset 0)
# Ignoring wrong pointing object 3333 0 (offset 0)
# Ignoring wrong pointing object 3336 0 (offset 0)
# Ignoring wrong pointing object 3339 0 (offset 0)
# Ignoring wrong pointing object 3342 0 (offset 0)
# Ignoring wrong pointing object 3345 0 (offset 0)
# Ignoring wrong pointing object 3348 0 (offset 0)
# Ignoring wrong pointing object 3352 0 (offset 0)
# Ignoring wrong pointing object 3355 0 (offset 0)
# Ignoring wrong pointing object 3358 0 (offset 0)
# Ignoring wrong pointing object 3361 0 (offset 0)
# Ignoring wrong pointing object 3364 0 (offset 0)
# Ignoring wrong pointing object 3367 0 (offset 0)
# Ignoring wrong pointing object 3370 0 (offset 0)
# Ignoring wrong pointing object 3373 0 (offset 0)
# Ignoring wrong pointing object 3376 0 (offset 0)
# Ignoring wrong pointing object 3379 0 (offset 0)
# Ignoring wrong pointing object 3382 0 (offset 0)
# Ignoring wrong pointing object 3385 0 (offset 0)
# Ignoring wrong pointing object 3388 0 (offset 0)
# Ignoring wrong pointing object 3391 0 (offset 0)
# Ignoring wrong pointing object 3394 0 (offset 0)
# Ignoring wrong pointing object 3397 0 (offset 0)
# Ignoring wrong pointing object 3400 0 (offset 0)
# Ignoring wrong pointing object 3403 0 (offset 0)
# Ignoring wrong pointing object 3406 0 (offset 0)
# Ignoring wrong pointing object 3409 0 (offset 0)
# Ignoring wrong pointing object 3412 0 (offset 0)
# Ignoring wrong pointing object 3416 0 (offset 0)
# Ignoring wrong pointing object 3419 0 (offset 0)
# Ignoring wrong pointing object 3422 0 (offset 0)
# Ignoring wrong pointing object 3425 0 (offset 0)
# Ignoring wrong pointing object 3428 0 (offset 0)
# Ignoring wrong pointing object 3431 0 (offset 0)
# Ignoring wrong pointing object 3434 0 (offset 0)
# Ignoring wrong pointing object 3437 0 (offset 0)
# Ignoring wrong pointing object 3440 0 (offset 0)
# Ignoring wrong pointing object 3443 0 (offset 0)
# Ignoring wrong pointing object 3446 0 (offset 0)
# Ignoring wrong pointing object 3449 0 (offset 0)
# Ignoring wrong pointing object 3452 0 (offset 0)
# Ignoring wrong pointing object 3455 0 (offset 0)
# Ignoring wrong pointing object 3458 0 (offset 0)
# Ignoring wrong pointing object 3461 0 (offset 0)
# Ignoring wrong pointing object 3464 0 (offset 0)
# Ignoring wrong pointing object 3467 0 (offset 0)
# Ignoring wrong pointing object 3470 0 (offset 0)
# Ignoring wrong pointing object 3473 0 (offset 0)
# Ignoring wrong pointing object 3476 0 (offset 0)
# Ignoring wrong pointing object 3479 0 (offset 0)
# Ignoring wrong pointing object 3482 0 (offset 0)
# Ignoring wrong pointing object 3485 0 (offset 0)
# Ignoring wrong pointing object 3488 0 (offset 0)
# Ignoring wrong pointing object 3491 0 (offset 0)
# Ignoring wrong pointing object 3494 0 (offset 0)
# Ignoring wrong pointing object 3497 0 (offset 0)
# Ignoring wrong pointing object 3500 0 (offset 0)
# Ignoring wrong pointing object 3503 0 (offset 0)
# Ignoring wrong pointing object 3506 0 (offset 0)
# Ignoring wrong pointing object 3509 0 (offset 0)
# Ignoring wrong pointing object 3512 0 (offset 0)
# Ignoring wrong pointing object 3515 0 (offset 0)
# Ignoring wrong pointing object 3518 0 (offset 0)
# Ignoring wrong pointing object 3521 0 (offset 0)
# Ignoring wrong pointing object 3524 0 (offset 0)
# Ignoring wrong pointing object 3527 0 (offset 0)
# Ignoring wrong pointing object 3530 0 (offset 0)
# Ignoring wrong pointing object 3533 0 (offset 0)
# Ignoring wrong pointing object 3536 0 (offset 0)
# Ignoring wrong pointing object 3539 0 (offset 0)
# Ignoring wrong pointing object 3542 0 (offset 0)
# Ignoring wrong pointing object 3545 0 (offset 0)
# Ignoring wrong pointing object 3548 0 (offset 0)
# Ignoring wrong pointing object 3551 0 (offset 0)
# Ignoring wrong pointing object 3554 0 (offset 0)
# Ignoring wrong pointing object 3557 0 (offset 0)
# Ignoring wrong pointing object 3560 0 (offset 0)
# Ignoring wrong pointing object 3563 0 (offset 0)
# Ignoring wrong pointing object 3566 0 (offset 0)
# Ignoring wrong pointing object 3569 0 (offset 0)
# Ignoring wrong pointing object 3572 0 (offset 0)
# Ignoring wrong pointing object 3576 0 (offset 0)
# Ignoring wrong pointing object 3579 0 (offset 0)
# Ignoring wrong pointing object 3582 0 (offset 0)
# Ignoring wrong pointing object 3585 0 (offset 0)
# Ignoring wrong pointing object 3588 0 (offset 0)
# Ignoring wrong pointing object 3591 0 (offset 0)
# Ignoring wrong pointing object 3594 0 (offset 0)
# Ignoring wrong pointing object 3597 0 (offset 0)
# Ignoring wrong pointing object 3600 0 (offset 0)
# Ignoring wrong pointing object 3603 0 (offset 0)
# Ignoring wrong pointing object 3606 0 (offset 0)
# Ignoring wrong pointing object 3609 0 (offset 0)
# Ignoring wrong pointing object 3612 0 (offset 0)
# Ignoring wrong pointing object 3615 0 (offset 0)
# Ignoring wrong pointing object 3618 0 (offset 0)
# Ignoring wrong pointing object 3621 0 (offset 0)
# Ignoring wrong pointing object 3624 0 (offset 0)
# Ignoring wrong pointing object 3627 0 (offset 0)
# Ignoring wrong pointing object 3630 0 (offset 0)
# Ignoring wrong pointing object 3633 0 (offset 0)
# Ignoring wrong pointing object 3636 0 (offset 0)
# Ignoring wrong pointing object 3639 0 (offset 0)
# Ignoring wrong pointing object 3642 0 (offset 0)
# Ignoring wrong pointing object 3645 0 (offset 0)
# Ignoring wrong pointing object 3648 0 (offset 0)
# Ignoring wrong pointing object 3651 0 (offset 0)
# Ignoring wrong pointing object 3654 0 (offset 0)
# Ignoring wrong pointing object 3658 0 (offset 0)
# Ignoring wrong pointing object 3661 0 (offset 0)
# Ignoring wrong pointing object 3664 0 (offset 0)
# Ignoring wrong pointing object 3667 0 (offset 0)
# Ignoring wrong pointing object 3670 0 (offset 0)
# Ignoring wrong pointing object 3673 0 (offset 0)
# Ignoring wrong pointing object 3676 0 (offset 0)
# Ignoring wrong pointing object 3679 0 (offset 0)
# Ignoring wrong pointing object 3683 0 (offset 0)
# Ignoring wrong pointing object 3686 0 (offset 0)
# Ignoring wrong pointing object 3690 0 (offset 0)
# Ignoring wrong pointing object 3694 0 (offset 0)
# Ignoring wrong pointing object 3697 0 (offset 0)
# Ignoring wrong pointing object 3700 0 (offset 0)
# Ignoring wrong pointing object 3703 0 (offset 0)
# Ignoring wrong pointing object 3706 0 (offset 0)
# Ignoring wrong pointing object 3709 0 (offset 0)
# Ignoring wrong pointing object 3712 0 (offset 0)
# Ignoring wrong pointing object 3715 0 (offset 0)
# Ignoring wrong pointing object 3718 0 (offset 0)
# Ignoring wrong pointing object 3721 0 (offset 0)
# Ignoring wrong pointing object 3724 0 (offset 0)
# Ignoring wrong pointing object 3727 0 (offset 0)
# Ignoring wrong pointing object 3730 0 (offset 0)
# Ignoring wrong pointing object 3734 0 (offset 0)
# Ignoring wrong pointing object 3738 0 (offset 0)
# Ignoring wrong pointing object 3743 0 (offset 0)
# Ignoring wrong pointing object 3746 0 (offset 0)
# Ignoring wrong pointing object 3749 0 (offset 0)
# Ignoring wrong pointing object 3752 0 (offset 0)
# Ignoring wrong pointing object 3756 0 (offset 0)
# Ignoring wrong pointing object 3759 0 (offset 0)
# Ignoring wrong pointing object 3762 0 (offset 0)
# Ignoring wrong pointing object 3765 0 (offset 0)
# Ignoring wrong pointing object 3768 0 (offset 0)
# Ignoring wrong pointing object 3771 0 (offset 0)
# Ignoring wrong pointing object 3774 0 (offset 0)
# Ignoring wrong pointing object 3777 0 (offset 0)
# Ignoring wrong pointing object 3781 0 (offset 0)
# Ignoring wrong pointing object 3784 0 (offset 0)
# Ignoring wrong pointing object 3787 0 (offset 0)
# Ignoring wrong pointing object 3790 0 (offset 0)
# Ignoring wrong pointing object 3793 0 (offset 0)
# Ignoring wrong pointing object 3796 0 (offset 0)
# Ignoring wrong pointing object 3799 0 (offset 0)
# Ignoring wrong pointing object 3802 0 (offset 0)
# Ignoring wrong pointing object 3805 0 (offset 0)
# Ignoring wrong pointing object 3808 0 (offset 0)
# Ignoring wrong pointing object 3812 0 (offset 0)
# ...
# Ignoring wrong pointing object 20279 0 (offset 0)
# Ignoring wrong pointing object 20280 0 (offset 0)
# Ignoring wrong pointing object 20281 0 (offset 0)
# Ignoring wrong pointing object 20282 0 (offset 0)
# Ignoring wrong pointing object 20283 0 (offset 0)
# Ignoring wrong pointing object 20284 0 (offset 0)
# Ignoring wrong pointing object 20285 0 (offset 0)
# Ignoring wrong pointing object 20286 0 (offset 0)
# Ignoring wrong pointing object 20287 0 (offset 0)
# Ignoring wrong pointing object 20288 0 (offset 0)
# Ignoring wrong pointing object 20289 0 (offset 0)
# Ignoring wrong pointing object 20290 0 (offset 0)
# Ignoring wrong pointing object 20291 0 (offset 0)
# Ignoring wrong pointing object 20292 0 (offset 0)
# Ignoring wrong pointing object 20293 0 (offset 0)
# Ignoring wrong pointing object 20294 0 (offset 0)
# Ignoring wrong pointing object 20295 0 (offset 0)
# Ignoring wrong pointing object 20296 0 (offset 0)
# Ignoring wrong pointing object 20297 0 (offset 0)
# Ignoring wrong pointing object 20298 0 (offset 0)
# Ignoring wrong pointing object 20299 0 (offset 0)
# Ignoring wrong pointing object 20300 0 (offset 0)
# Ignoring wrong pointing object 20301 0 (offset 0)
# Ignoring wrong pointing object 20311 0 (offset 0)
# Ignoring wrong pointing object 20312 0 (offset 0)
# Ignoring wrong pointing object 20313 0 (offset 0)
# Ignoring wrong pointing object 20314 0 (offset 0)
# Ignoring wrong pointing object 20315 0 (offset 0)
# Ignoring wrong pointing object 20316 0 (offset 0)
# Ignoring wrong pointing object 20317 0 (offset 0)
# Ignoring wrong pointing object 20318 0 (offset 0)
# Ignoring wrong pointing object 20319 0 (offset 0)
# Ignoring wrong pointing object 20320 0 (offset 0)
# Ignoring wrong pointing object 20321 0 (offset 0)
# Ignoring wrong pointing object 20322 0 (offset 0)
# Ignoring wrong pointing object 20323 0 (offset 0)
# Ignoring wrong pointing object 20324 0 (offset 0)
# Ignoring wrong pointing object 20325 0 (offset 0)
# Ignoring wrong pointing object 20326 0 (offset 0)
# Ignoring wrong pointing object 20327 0 (offset 0)
# Ignoring wrong pointing object 20328 0 (offset 0)
# Ignoring wrong pointing object 20329 0 (offset 0)
# Ignoring wrong pointing object 20330 0 (offset 0)
# Ignoring wrong pointing object 20331 0 (offset 0)
# Ignoring wrong pointing object 20332 0 (offset 0)
# Ignoring wrong pointing object 20333 0 (offset 0)
# Ignoring wrong pointing object 20334 0 (offset 0)
# Ignoring wrong pointing object 20335 0 (offset 0)
# Ignoring wrong pointing object 20336 0 (offset 0)
# Ignoring wrong pointing object 20337 0 (offset 0)
# Ignoring wrong pointing object 20338 0 (offset 0)
# Ignoring wrong pointing object 20339 0 (offset 0)
# Ignoring wrong pointing object 20340 0 (offset 0)
# Ignoring wrong pointing object 20341 0 (offset 0)
# Ignoring wrong pointing object 20342 0 (offset 0)
# Ignoring wrong pointing object 20343 0 (offset 0)
# Ignoring wrong pointing object 20344 0 (offset 0)
# Ignoring wrong pointing object 20345 0 (offset 0)
# Ignoring wrong pointing object 20346 0 (offset 0)
# Ignoring wrong pointing object 20347 0 (offset 0)
# Ignoring wrong pointing object 20348 0 (offset 0)
# Ignoring wrong pointing object 20349 0 (offset 0)
# Ignoring wrong pointing object 20350 0 (offset 0)
# Ignoring wrong pointing object 20351 0 (offset 0)
# Ignoring wrong pointing object 20352 0 (offset 0)
# Ignoring wrong pointing object 20353 0 (offset 0)
# Ignoring wrong pointing object 20354 0 (offset 0)
# Ignoring wrong pointing object 20355 0 (offset 0)
# Ignoring wrong pointing object 20356 0 (offset 0)
# Ignoring wrong pointing object 20357 0 (offset 0)
# Ignoring wrong pointing object 20358 0 (offset 0)
# Ignoring wrong pointing object 20359 0 (offset 0)
# Ignoring wrong pointing object 20360 0 (offset 0)
# Ignoring wrong pointing object 20361 0 (offset 0)
# Ignoring wrong pointing object 20362 0 (offset 0)
# Ignoring wrong pointing object 20363 0 (offset 0)
# Ignoring wrong pointing object 20364 0 (offset 0)
# Ignoring wrong pointing object 20365 0 (offset 0)
# Ignoring wrong pointing object 20366 0 (offset 0)
# Ignoring wrong pointing object 20367 0 (offset 0)
# Ignoring wrong pointing object 20368 0 (offset 0)
# Ignoring wrong pointing object 20369 0 (offset 0)
# Ignoring wrong pointing object 20370 0 (offset 0)
# Ignoring wrong pointing object 20371 0 (offset 0)
# Ignoring wrong pointing object 20372 0 (offset 0)
# Ignoring wrong pointing object 20373 0 (offset 0)
# Ignoring wrong pointing object 20374 0 (offset 0)
# Ignoring wrong pointing object 20375 0 (offset 0)
# Ignoring wrong pointing object 20376 0 (offset 0)
# Ignoring wrong pointing object 20377 0 (offset 0)
# Ignoring wrong pointing object 20378 0 (offset 0)
# Ignoring wrong pointing object 20379 0 (offset 0)
# Ignoring wrong pointing object 20380 0 (offset 0)
# Ignoring wrong pointing object 20381 0 (offset 0)
# Ignoring wrong pointing object 20382 0 (offset 0)
# Ignoring wrong pointing object 20383 0 (offset 0)
# Ignoring wrong pointing object 20384 0 (offset 0)
# Ignoring wrong pointing object 20385 0 (offset 0)
# Ignoring wrong pointing object 20386 0 (offset 0)
# Ignoring wrong pointing object 20387 0 (offset 0)
# Ignoring wrong pointing object 20388 0 (offset 0)
# Ignoring wrong pointing object 20389 0 (offset 0)
# Ignoring wrong pointing object 20390 0 (offset 0)
# Ignoring wrong pointing object 20391 0 (offset 0)
# Ignoring wrong pointing object 20392 0 (offset 0)
# Ignoring wrong pointing object 20393 0 (offset 0)
# Ignoring wrong pointing object 20394 0 (offset 0)
# Ignoring wrong pointing object 20395 0 (offset 0)
# Ignoring wrong pointing object 20396 0 (offset 0)
# Ignoring wrong pointing object 20397 0 (offset 0)
# Ignoring wrong pointing object 20398 0 (offset 0)
# Ignoring wrong pointing object 20399 0 (offset 0)
# Ignoring wrong pointing object 20400 0 (offset 0)
# Ignoring wrong pointing object 20401 0 (offset 0)
# Ignoring wrong pointing object 20402 0 (offset 0)
# Ignoring wrong pointing object 20403 0 (offset 0)
# Ignoring wrong pointing object 20404 0 (offset 0)
# Ignoring wrong pointing object 20405 0 (offset 0)
# Ignoring wrong pointing object 20406 0 (offset 0)
# Ignoring wrong pointing object 20407 0 (offset 0)
# Ignoring wrong pointing object 20408 0 (offset 0)
# Ignoring wrong pointing object 20409 0 (offset 0)
# Ignoring wrong pointing object 20410 0 (offset 0)
# Ignoring wrong pointing object 20411 0 (offset 0)
# Ignoring wrong pointing object 20412 0 (offset 0)
# Ignoring wrong pointing object 20413 0 (offset 0)
# Ignoring wrong pointing object 20414 0 (offset 0)
# Ignoring wrong pointing object 20415 0 (offset 0)
# Ignoring wrong pointing object 20416 0 (offset 0)
# Ignoring wrong pointing object 20417 0 (offset 0)
# Ignoring wrong pointing object 20418 0 (offset 0)
# Ignoring wrong pointing object 20419 0 (offset 0)
# Ignoring wrong pointing object 20420 0 (offset 0)
# Ignoring wrong pointing object 20421 0 (offset 0)
# Ignoring wrong pointing object 20422 0 (offset 0)
# Ignoring wrong pointing object 20423 0 (offset 0)
# Ignoring wrong pointing object 20424 0 (offset 0)
# Ignoring wrong pointing object 20425 0 (offset 0)
# Ignoring wrong pointing object 20426 0 (offset 0)
# Ignoring wrong pointing object 20427 0 (offset 0)
# Ignoring wrong pointing object 20428 0 (offset 0)
# Ignoring wrong pointing object 20429 0 (offset 0)
# Ignoring wrong pointing object 20430 0 (offset 0)
# Ignoring wrong pointing object 20431 0 (offset 0)
# Ignoring wrong pointing object 20432 0 (offset 0)
# Ignoring wrong pointing object 20433 0 (offset 0)
# Ignoring wrong pointing object 20434 0 (offset 0)
# Ignoring wrong pointing object 20435 0 (offset 0)
# Ignoring wrong pointing object 20436 0 (offset 0)
# Ignoring wrong pointing object 20437 0 (offset 0)
# Ignoring wrong pointing object 20438 0 (offset 0)
# Ignoring wrong pointing object 20439 0 (offset 0)
# Ignoring wrong pointing object 20440 0 (offset 0)
# Ignoring wrong pointing object 20441 0 (offset 0)
# Ignoring wrong pointing object 20442 0 (offset 0)
# Ignoring wrong pointing object 20443 0 (offset 0)
# Ignoring wrong pointing object 20444 0 (offset 0)
# Ignoring wrong pointing object 20445 0 (offset 0)
# Ignoring wrong pointing object 20446 0 (offset 0)
# Ignoring wrong pointing object 20447 0 (offset 0)
# Ignoring wrong pointing object 20448 0 (offset 0)
# Ignoring wrong pointing object 20449 0 (offset 0)
# Ignoring wrong pointing object 20450 0 (offset 0)
# Ignoring wrong pointing object 20451 0 (offset 0)
# Ignoring wrong pointing object 20452 0 (offset 0)
# Ignoring wrong pointing object 20453 0 (offset 0)
# Ignoring wrong pointing object 20454 0 (offset 0)
# Ignoring wrong pointing object 20455 0 (offset 0)
# Ignoring wrong pointing object 20456 0 (offset 0)
# Ignoring wrong pointing object 20457 0 (offset 0)
# Ignoring wrong pointing object 20458 0 (offset 0)
# Ignoring wrong pointing object 20459 0 (offset 0)
# Ignoring wrong pointing object 20460 0 (offset 0)
# Ignoring wrong pointing object 20461 0 (offset 0)
# Ignoring wrong pointing object 20462 0 (offset 0)
# Ignoring wrong pointing object 20463 0 (offset 0)
# Ignoring wrong pointing object 20464 0 (offset 0)
# Ignoring wrong pointing object 20465 0 (offset 0)
# Ignoring wrong pointing object 20466 0 (offset 0)
# Ignoring wrong pointing object 20467 0 (offset 0)
# Ignoring wrong pointing object 20468 0 (offset 0)
# Ignoring wrong pointing object 20469 0 (offset 0)
# Ignoring wrong pointing object 20470 0 (offset 0)
# Ignoring wrong pointing object 20471 0 (offset 0)
# Ignoring wrong pointing object 20472 0 (offset 0)
# Ignoring wrong pointing object 20473 0 (offset 0)
# Ignoring wrong pointing object 20474 0 (offset 0)
# Ignoring wrong pointing object 20475 0 (offset 0)
# Ignoring wrong pointing object 20476 0 (offset 0)
# Ignoring wrong pointing object 20477 0 (offset 0)
# Ignoring wrong pointing object 20478 0 (offset 0)
# Ignoring wrong pointing object 20479 0 (offset 0)
# Ignoring wrong pointing object 20480 0 (offset 0)
# Ignoring wrong pointing object 20481 0 (offset 0)
# Ignoring wrong pointing object 20482 0 (offset 0)
# Ignoring wrong pointing object 20483 0 (offset 0)
# Ignoring wrong pointing object 20484 0 (offset 0)
# Ignoring wrong pointing object 20485 0 (offset 0)
# Ignoring wrong pointing object 20486 0 (offset 0)
# Ignoring wrong pointing object 20487 0 (offset 0)
# Ignoring wrong pointing object 20488 0 (offset 0)
# Ignoring wrong pointing object 20489 0 (offset 0)
# Ignoring wrong pointing object 20490 0 (offset 0)
# Ignoring wrong pointing object 20491 0 (offset 0)
# Ignoring wrong pointing object 20492 0 (offset 0)
# Ignoring wrong pointing object 20493 0 (offset 0)
# Ignoring wrong pointing object 20494 0 (offset 0)
# Ignoring wrong pointing object 20495 0 (offset 0)
# Ignoring wrong pointing object 20496 0 (offset 0)
# Ignoring wrong pointing object 20497 0 (offset 0)
# Ignoring wrong pointing object 20498 0 (offset 0)
# Ignoring wrong pointing object 20499 0 (offset 0)
# Ignoring wrong pointing object 20500 0 (offset 0)
# Ignoring wrong pointing object 20501 0 (offset 0)
# Ignoring wrong pointing object 20502 0 (offset 0)
# Ignoring wrong pointing object 20503 0 (offset 0)
# Ignoring wrong pointing object 20504 0 (offset 0)
# Ignoring wrong pointing object 20505 0 (offset 0)
# Ignoring wrong pointing object 20506 0 (offset 0)
# Ignoring wrong pointing object 20507 0 (offset 0)
# Ignoring wrong pointing object 20508 0 (offset 0)
# Ignoring wrong pointing object 20509 0 (offset 0)
# Ignoring wrong pointing object 20510 0 (offset 0)
# Ignoring wrong pointing object 20511 0 (offset 0)
# Ignoring wrong pointing object 20512 0 (offset 0)
# Ignoring wrong pointing object 20513 0 (offset 0)
# Ignoring wrong pointing object 20514 0 (offset 0)
# Ignoring wrong pointing object 20515 0 (offset 0)
# Ignoring wrong pointing object 20516 0 (offset 0)
# Ignoring wrong pointing object 20517 0 (offset 0)
# Ignoring wrong pointing object 20518 0 (offset 0)
# Ignoring wrong pointing object 20519 0 (offset 0)
# Ignoring wrong pointing object 20520 0 (offset 0)
# Ignoring wrong pointing object 20521 0 (offset 0)
# Ignoring wrong pointing object 20522 0 (offset 0)
# Ignoring wrong pointing object 20523 0 (offset 0)
# Ignoring wrong pointing object 20524 0 (offset 0)
# Ignoring wrong pointing object 20525 0 (offset 0)
# Ignoring wrong pointing object 20526 0 (offset 0)
# Ignoring wrong pointing object 20527 0 (offset 0)
# Ignoring wrong pointing object 20528 0 (offset 0)
# Ignoring wrong pointing object 20530 0 (offset 0)
# Ignoring wrong pointing object 20531 0 (offset 0)
# Ignoring wrong pointing object 20532 0 (offset 0)
# Ignoring wrong pointing object 20533 0 (offset 0)
# Ignoring wrong pointing object 20534 0 (offset 0)
# Ignoring wrong pointing object 20535 0 (offset 0)
# Ignoring wrong pointing object 20536 0 (offset 0)
# Ignoring wrong pointing object 20537 0 (offset 0)
# Ignoring wrong pointing object 20538 0 (offset 0)
# Ignoring wrong pointing object 20540 0 (offset 0)
# Ignoring wrong pointing object 20541 0 (offset 0)
# Ignoring wrong pointing object 20542 0 (offset 0)
# Ignoring wrong pointing object 20543 0 (offset 0)
# Ignoring wrong pointing object 20553 0 (offset 0)
# Ignoring wrong pointing object 23573 0 (offset 0)
# Ignoring wrong pointing object 23574 0 (offset 0)
# Ignoring wrong pointing object 23575 0 (offset 0)
# Ignoring wrong pointing object 23576 0 (offset 0)
# Ignoring wrong pointing object 23577 0 (offset 0)
# Ignoring wrong pointing object 23578 0 (offset 0)
# Ignoring wrong pointing object 23579 0 (offset 0)
# Ignoring wrong pointing object 23580 0 (offset 0)
# Ignoring wrong pointing object 23581 0 (offset 0)
# Ignoring wrong pointing object 23582 0 (offset 0)
# Ignoring wrong pointing object 23583 0 (offset 0)
# Ignoring wrong pointing object 23584 0 (offset 0)
# Ignoring wrong pointing object 23585 0 (offset 0)
# Ignoring wrong pointing object 23586 0 (offset 0)
# Ignoring wrong pointing object 23587 0 (offset 0)
# Ignoring wrong pointing object 23588 0 (offset 0)
# Ignoring wrong pointing object 23589 0 (offset 0)
# Ignoring wrong pointing object 23590 0 (offset 0)
# Ignoring wrong pointing object 23591 0 (offset 0)
# Ignoring wrong pointing object 23592 0 (offset 0)
# Ignoring wrong pointing object 23593 0 (offset 0)
# Ignoring wrong pointing object 23594 0 (offset 0)
# Ignoring wrong pointing object 23595 0 (offset 0)
# Ignoring wrong pointing object 23596 0 (offset 0)
# Ignoring wrong pointing object 23597 0 (offset 0)
# Ignoring wrong pointing object 23598 0 (offset 0)
# Ignoring wrong pointing object 23599 0 (offset 0)
# Ignoring wrong pointing object 23600 0 (offset 0)
# Ignoring wrong pointing object 23601 0 (offset 0)
# Ignoring wrong pointing object 23602 0 (offset 0)
# Ignoring wrong pointing object 23603 0 (offset 0)
# Ignoring wrong pointing object 23604 0 (offset 0)
# Ignoring wrong pointing object 23605 0 (offset 0)
# Ignoring wrong pointing object 23606 0 (offset 0)
# Ignoring wrong pointing object 23607 0 (offset 0)
# Ignoring wrong pointing object 23608 0 (offset 0)
# Ignoring wrong pointing object 23609 0 (offset 0)
# Ignoring wrong pointing object 23610 0 (offset 0)
# Ignoring wrong pointing object 23611 0 (offset 0)
# Ignoring wrong pointing object 23612 0 (offset 0)
# Ignoring wrong pointing object 23613 0 (offset 0)
# Ignoring wrong pointing object 23614 0 (offset 0)
# Ignoring wrong pointing object 23615 0 (offset 0)
# Ignoring wrong pointing object 23616 0 (offset 0)
# Ignoring wrong pointing object 23617 0 (offset 0)
# Ignoring wrong pointing object 23618 0 (offset 0)
# Ignoring wrong pointing object 23619 0 (offset 0)
# Ignoring wrong pointing object 23620 0 (offset 0)
# Ignoring wrong pointing object 23621 0 (offset 0)
# Ignoring wrong pointing object 23622 0 (offset 0)
# Ignoring wrong pointing object 23623 0 (offset 0)
# Ignoring wrong pointing object 23624 0 (offset 0)
# Ignoring wrong pointing object 23625 0 (offset 0)
# Ignoring wrong pointing object 23626 0 (offset 0)
# Ignoring wrong pointing object 23627 0 (offset 0)
# Ignoring wrong pointing object 23628 0 (offset 0)
# Ignoring wrong pointing object 23629 0 (offset 0)
# Ignoring wrong pointing object 23630 0 (offset 0)
# Ignoring wrong pointing object 23631 0 (offset 0)
# Ignoring wrong pointing object 23632 0 (offset 0)
# Ignoring wrong pointing object 23633 0 (offset 0)
# Ignoring wrong pointing object 23634 0 (offset 0)
# Ignoring wrong pointing object 23635 0 (offset 0)
# Ignoring wrong pointing object 23636 0 (offset 0)
# Ignoring wrong pointing object 23637 0 (offset 0)

# %%
len(extracted_data)
# Out:
# 4153

# %%
from typing import List
from langchain.schema import Document

def filter_to_minimal_docs(docs: List[Document])-> List[Document]:

    minimal_docs: List[Document] = []
    for doc in docs:
        src = doc.metadata.get("source")
        minimal_docs.append(
            Document(
                page_content=doc.page_content,
                metadata={"source": src}
            )
        )
    return minimal_docs

# %%
minimal_docs = filter_to_minimal_docs(extracted_data)

# %%
len(minimal_docs)
# Out:
# 4153

# %%
# split the documents

def text_split(minimal_docs):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = 500,
        chunk_overlap = 20,
        length_function = len
    )

    texts_chunks = text_splitter.split_documents(minimal_docs)
    return texts_chunks

# %%
def sematic_text_split(minimal_docs):
    text_splitter = SemanticChunker(
        HuggingFaceEmbeddings(),
        breakpoint_threshold_type="standard_deviation",
        breakpoint_threshold_amount = 1
    )
    texts_chunks = text_splitter.split_documents(minimal_docs)

    return texts_chunks

# %%
texts_chunk = text_split(minimal_docs)

# %%
# sem_text_split = sematic_text_split(minimal_docs)

# %%
len(texts_chunk)
# Out:
# 28324

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
embedding = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')

# %%
vc = embedding.embed_documents([
    "Delhi is the capital of India.",
    "Beijing is the capital of China.",
    "Tokyo is the capital of Japan."
])

# %%
len(vc[0])
# Out:
# 384

# %%
embedding

# %%
from pinecone import Pinecone, ServerlessSpec
pc = Pinecone()

# %%
index_name = "upsc-sociology-chatbot"
if not pc.has_index(index_name):
    pc.create_index(
        name = index_name,
        dimension= 384,
        metric = 'cosine',
        spec= ServerlessSpec(cloud='aws', region='us-east-1') 
    )

# %%
index = pc.Index(index_name)

# %%
from langchain_pinecone import PineconeVectorStore

# %%
docsearch = PineconeVectorStore.from_documents(
    documents=texts_chunk,
    embedding=embedding,
    index_name=index_name
)

# %%
retriever = docsearch.as_retriever(search_type = "similarity", search_kwargs={"k":3})

# %%
retrieved_docs = retriever.invoke("Critically explain the salient features of ‘alienation’ as propounded by Karl Marx.")

# %%
retrieved_docs
# Out:
# [Document(id='ad20adc3-68c3-4253-a2d3-f2c8309bf322', metadata={'source': '/Users/anshugangwar/Desktop/Anshu/upsc_sociology_book_chatbot/data/Sociology-Tusharanshu Part 1 (UPSCPDF.com).pdf'}, page_content='alienation’. \nIn his Economic and Philosophical Manuscripts (EPM)\n published in 1844, Marx analyses various \naspects of alienation. \n1) Firstly, the worker is alienated from the produc\nt of his labour. The product in which he expresses \nand realises himself does not belong to him. It is \nappropriated by the capitalists and sold on the \nmarket. With realisation of surplus-value capital g\nrows, and with capital the alien power which \ncontrols and dominates the life of the worker. The'),
#  Document(id='b979cdc9-b191-49dc-af23-e58440431114', metadata={'source': '/Users/anshugangwar/Desktop/Anshu/upsc_sociology_book_chatbot/data/Sociology-Tusharanshu Part 1 (UPSCPDF.com).pdf'}, page_content='78 \n \nKARL MARX and ALIENATION \n \nAlienation literally means “separation from”.The co\nncept alienation describes the estrangement of \nindividuals from one another, or from a specific si\ntuation or process.Marx has conceived of \nalienation as a phenomenon related to the structure\n of those societies in which the producer is \ndivorced from the means of production and in which \n“\ndead labour” (capital) dominates “living \nlabour” (the worker).\n \nIn Marx’s analysis of bourgeois society, there are'),
#  Document(id='c98d2fa9-8bd7-4f79-842d-9f97d3af7782', metadata={'source': '/Users/anshugangwar/Desktop/Anshu/upsc_sociology_book_chatbot/data/BA IGNOU Sociology.pdf'}, page_content='through one’s own activity. To quote Gajo Petrovic (1983: 10) we can\nsay, “And self-alienation is not just one among the forms of alienation, but\nthe very essence and basic structure of alienation. It is not merely a\ndescriptive concept, it is also an appeal, or a call for a revolutionary change\nof the world”.\nDe-alienation\nMere criticism of alienation was not the intention of Marx. His aim was to\nclear the path for a radical revolution and for accomplishing communism')]

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm1 = HuggingFaceEndpoint(
    repo_id="google/gemma-2-2b-it",
    task='text-generation'
)
model = ChatHuggingFace(llm=llm1)

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

# %%
system_prompt = (
    """You are an assisstant for question-answering tasks. Use the following pieces of retrieved context to 
    answer the question. If you don't know the answer, say that you don't Know. Use 200 words maximum and keep
    answer to the point.\n\n
    {context}""")

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}")
    ]
)

# %%
question_answer_chain = create_stuff_documents_chain(model, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response = rag_chain.invoke({"input": "Critically explain the salient features of alienation as propounded by Karl Marx."})

# %%
Markdown(response['answer'])
# Out:
# Karl Marx's concept of alienation highlights the painful existence of workers within capitalist societies.  He viewed this alienation as an inherent aspect of modern capitalism, stemming from the disconnect between labor and the societal context within economic opportunity.
#
# Here are the core features of Marx's concept of alienation:
#
# * **Alienation from the Product of Labor:** Workers produce goods that are owned by someone else, depriving them of ownership over the fruits of their labor.
# * **Alienation From the Process of Production:** The reality of production in question is an abstraction, meaning individuals lack a connection to what they produced.
# * **Alienation From the Laborer Himself:** He sees the worker to be estranged from their own capacity for valuation and conscientiousness when disconnecting from their inherent human capabilities.
# * **Alienation from Others:**  The capitalist system compels individuals to work right away at the expense of healthy, meaningful interactions, displacing genuine connections inside of work and in life.
#
#
# These cracks permeate the classical workings of the human experience, rendering individuals as mere ciphers of the machine in this relationship, and exists to justify a system of exploitation. However, he suggested that such alienation would be resolved in a communist society, through worker cooperatives and collective ownership of the means of production, ushering in a new era of authentic for humans to thrive.
#
# **Criticism:**  Marx' expression of alienation is, certainly, a powerful lens for understanding how capitalism reshapes the human spirit. Some criticize the notion that it is entirely deterministic. Others suggest that many aspects of a capitalist society do not typically create heightened anxieties and are, in fact, largely avoided.

# %%
response = rag_chain.invoke({"input": "Describe various characteristics of a social fact. How is rate of suicide a social fact according to Durkheim"})

# %%
Markdown(response['answer'])
# Out:
# Emile Durkheim viewed social realities as encompassing established norms, beliefs, and behaviours that shape the phenomena of human interaction and society. Here's how they are characterized:
#
# **Characteristics of Social Facts:**
#
# * **Consistently Occurring**: Social facts are not merely individual experiences but a collective phenomenon that unfolds across numerous individuals within a given society.
# * **Irrational in Nature**: They do not imply personal desires or internal motivations; they represent facts understood through the statistical patterns of social aggregates. Social facts change gradually with societal structures and values, just like political systems, economic relations, or religious ideologies.
# * **External to Individuals**: Social facts impose upon individuals, influencing their actions and thoughts but it is the collective nature that brings them into existence.
#
# **Rate of Suicide and Social Fact Status:**
#
# According to Durkheim, the rate of suicide is a social fact. This is because:
#
# * **Statistical Pattern**: While motivations might vary, the  suicide rate is neither a simple individual matter nor a random occurrence. Statistics show a significant and recurring transmission of self-destructive behaviour that transcends individual psychology.
# * **Social Consequence**:  Durkheim points out that even though we have personal beliefs and perceptions regarding the morality of suicide, the increasing rates in certain societies act as a social intrusion.
# * **Integrative Potential**: Every society has a 'normal' (or often a 'high') rate of suicide, allowing social groups to adhere to binding norms and organizations within the social fact cornerstone.
#
#
# However it is important to note that Durkheim acknowledged that psychological factors likely contribute to suicidal behaviour; but a primary focus is the societal implications, illustrating the intricate balance between individual psychology, and the social context.

# %%
import re

def clean_chatbot_output(text):
    """
    Cleans chatbot output by removing markdown and special characters.

    Args:
        text (str): The raw text from the chatbot model.

    Returns:
        str: The cleaned, readable text.
    """
    # Remove asterisks used for bolding or lists
    text = re.sub(r'\*', '', text)
    # Remove bullet points (e.g., '-', '*') and extra spaces
    text = re.sub(r'•\s*|\-\s*', '', text)
    # Remove excessive newlines, keeping only a single line break between paragraphs
    text = re.sub(r'\n\s*\n', '\n\n', text.strip())
    # Remove any leading/trailing whitespace
    text = text.strip()
    return text

# Example of how to use the function
raw_output = """
According to Durkheim, various characteristics define a social fact: * **Measurable:** Social facts, like births, deaths, and marriages, can be statistically measured. This means we can collect data to understand the trends and variations in them. * **Objective:** Socially relevant concepts, like suicide rates, exist independently of individual thoughts or desires. * **Universal:** They tend to exist and display consistent patterns across different societies, cultures, and periods of time. This means what's considered normal in one society might be different in another. * **Adaptive:** They are viewed as an organic organization that reflects how humans create and sustain their social life. Durkheim argues that suicide rates, even though it might be viewed as an "immoral" act, must be analyzed from a broader societal perspective. This is because suicide rates present, according to him, a form of collective anxiety and are reflective of of social integration and regulation. Essentially, a social fact is relatively autonomous of individual beliefs, and can inform us about larger social forces that shape human behavior.
"""

cleaned_output = clean_chatbot_output(raw_output)
print(cleaned_output)
# Out:
# According to Durkheim, various characteristics define a social fact:  Measurable: Social facts, like births, deaths, and marriages, can be statistically measured. This means we can collect data to understand the trends and variations in them.  Objective: Socially relevant concepts, like suicide rates, exist independently of individual thoughts or desires.  Universal: They tend to exist and display consistent patterns across different societies, cultures, and periods of time. This means what's considered normal in one society might be different in another.  Adaptive: They are viewed as an organic organization that reflects how humans create and sustain their social life. Durkheim argues that suicide rates, even though it might be viewed as an "immoral" act, must be analyzed from a broader societal perspective. This is because suicide rates present, according to him, a form of collective anxiety and are reflective of of social integration and regulation. Essentially, a social fact is relatively autonomous of individual beliefs, and can inform us about larger social forces that shape human behavior.
